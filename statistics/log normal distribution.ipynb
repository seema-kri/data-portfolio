# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("income.csv")
df.head()
# Out:
#    income($)  count
# 0       5000   4371
# 1      10000   3295
# 2      15000   5825
# 3      20000   6047
# 4      25000   6097

# %%
df.rename(columns={"income($)":"income"},inplace=True)

# %%
df.head()
# Out:
#    income  count
# 0    5000   4371
# 1   10000   3295
# 2   15000   5825
# 3   20000   6047
# 4   25000   6097

# %%
sns.barplot(x="income",y="count",data=df)
plt.tittle=("income vs count")
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(x="income",y="count",data=df)
plt.xscale("log")
plt.title("income vs count(log)")
plt.show()

# %% [markdown]
# # handle 0

# %%
x=np.array([0,10,20,20])
np.log(x)
# Out:
# C:\Users\krise\AppData\Local\Temp\ipykernel_1084\1422744983.py:2: RuntimeWarning: divide by zero encountered in log
#   np.log(x)
# array([      -inf, 2.30258509, 2.99573227, 2.99573227])

# %%
np.log1p(x)
# Out:
# array([0.        , 2.39789527, 3.04452244, 3.04452244])
